# %% [markdown]
# # MODULES

# %%
# !pip install pathlib
# !pip install matplotlib
# Out:
# Requirement already satisfied: pathlib in /home/zionsflow/anaconda3/envs/fallDetec/lib/python3.10/site-packages (1.0.1)
# Requirement already satisfied: matplotlib in /home/zionsflow/anaconda3/envs/fallDetec/lib/python3.10/site-packages (3.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/zionsflow/anaconda3/envs/fallDetec/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/zionsflow/anaconda3/envs/fallDetec/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/zionsflow/anaconda3/envs/fallDetec/lib/python3.10/site-packages (from matplotlib) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/zionsflow/anaconda3/envs/fallDetec/lib/python3.10/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /home/zionsflow/anaconda3/envs/fallDetec/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/zionsflow/anaconda3/envs/fallDetec/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/zionsflow/anaconda3/envs/fallDetec/lib/python3.10/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/zionsflow/anaconda3/envs/fallDetec/lib/python3.10/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/zionsflow/anaconda3/envs/fallDetec/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/zionsflow/anaconda3/envs/fallDetec/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# !nvidia-smi
# Out:
# Sat Oct 11 19:33:59 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.247.01             Driver Version: 535.247.01   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3060        Off | 00000000:01:00.0  On |                  N/A |
# |  0%   50C    P8              17W / 170W |    262MiB / 12288MiB |     34%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      1237      G   /usr/lib/xorg/Xorg                          134MiB |
# |    0   N/A  N/A      1527      G   /usr/bin/gnome-shell                         46MiB |
# |    0   N/A  N/A    963267      G   ...seed-version=20251005-180042.197000       71MiB |
# +---------------------------------------------------------------------------------------+

# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
print(torch.cuda.get_device_name(0))
# Out:
# 1.13.1+cu117
# 11.7
# NVIDIA GeForce RTX 3060

# %%
import cv2
import os
import math
import time
import random
import pathlib
import numpy as np
from ultralytics import YOLO
import matplotlib.pyplot as plt

# %% [markdown]
# # GLOBAL VARIABLES

# %%
ROOT_DIR_IMAGES = '../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation'

# %% [markdown]
# # VIDEOS

# %%
def get_videos_fall(root_dir, folders):
    paths = []

    for folder in folders:
        target = pathlib.Path(root_dir) / folder
        print(target)
        for path in (target / 'Fall').glob('*.mp4'):
            paths.append(path)

    return paths


def get_videos_no_fall(root_dir, folders):
    paths = []

    for folder in folders:
        target = pathlib.Path(root_dir) / folder
        print(target)
        for path in (target / 'ADL').glob('*.mp4'):
            paths.append(path)

    return paths



def save_images(images, refPath, prefix="crop"):
    os.makedirs(refPath, exist_ok=True)  # create folder if it doesn't exist

    for i, img in enumerate(images):
        # Build filename: e.g., crop_0.png, crop_1.png, ...
        filename = os.path.join(refPath, f"{prefix}_{i}.jpeg")

        # OpenCV expects uint8 images; convert if needed
        if img.dtype != 'uint8':
            img_to_save = (img * 255).astype('uint8') if img.max() <= 1 else img.astype('uint8')
        else:
            img_to_save = img

        # Save image
        cv2.imwrite(filename, img_to_save)

    print(f"Saved {len(images)} images to {refPath}")

# %%
videos = {}
videos['fall']     = get_videos_fall( ROOT_DIR_IMAGES, ['Subject 1', 'Subject 2', 'Subject 3', 'Subject 4'] )
videos['no_fall'] = get_videos_no_fall( ROOT_DIR_IMAGES, ['Subject 1', 'Subject 2', 'Subject 3', 'Subject 4'] )

print(f"[INFO] videos dict keys: {list(videos.keys())}")
print(f"[INFO] videos['fall'] has {len(videos['fall'])} entries")
print(f"[INFO] videos['no_fall'] has {len(videos['no_fall'])} entries")
# Out:
# ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 1
# ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 2
# ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 3
# ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 4
# ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 1
# ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 2
# ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 3
# ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 4
# [INFO] videos dict keys: ['fall', 'no_fall']
# [INFO] videos['fall'] has 79 entries
# [INFO] videos['no_fall'] has 81 entries

# %%
def get_person_crops(video_path, model_path="yolov8l.pt", conf_thres=0.5):
    """
    Reads a video, applies YOLO person detection, and returns cropped person images.

    Args:
        video_path (str): Path to the .mp4 video
        model_path (str): Path to YOLO model (default = yolov8n.pt)
        conf_thres (float): Confidence threshold for detection

    Returns:
        List of cropped person images (numpy arrays in BGR)
    """
    # Load YOLO
    model = YOLO(model_path)

    crops = []
    cap = cv2.VideoCapture(str(video_path))

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Run YOLO detection on frame
        results = model(frame, conf=conf_thres, verbose=False)

        # Extract person detections (class 0 in COCO)
        for box in results[0].boxes:
            cls = int(box.cls[0])
            if cls == 0:  # person
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                crop = frame[y1:y2, x1:x2]
                if crop.size > 0:
                    crops.append(crop)

    cap.release()
    return crops

def resize_images(imgs, size=(300,300)):
  lst = []
  for img in imgs:
    lst.append(cv2.resize(img, size))
  return lst


def sub_sample(lst, elens=25):
    """
    Subsample a list to have at most `elens` elements, evenly spaced.
    Indices are generated first to avoid repetition.

    Args:
        lst (list): Input list
        elens (int): Desired number of elements

    Returns:
        list: Subsampled list
    """
    n = len(lst)
    if n <= elens:
        return lst, list(range(n))

    step = n / elens
    indices = [int(i * step) for i in range(elens)]
    indices = list(dict.fromkeys(indices))  # remove any accidental repetitions

    return [lst[i] for i in indices], indices

# %%
path = videos['fall'][0]
print(path)
crops = get_person_crops(path, model_path='yolo11l.pt')
# Out:
# ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 1/Fall/13.mp4

# %%
crops_resized = resize_images(crops, (100, 100))
crops_resized_sample, _ = sub_sample(crops_resized, 20)
array = np.concatenate(crops_resized_sample, axis=1)  # axis=1 → horizontal concat

# %%
plt.figure(figsize=(40, 2))  # width=12in, height=6in
plt.imshow(cv2.cvtColor(array, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %%
refPaths = {
    'fall' : '../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image',
    'no_fall' : '../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/No_Fall/Raw_Image'
}
key = 'fall'
start_from = 0
crops_number = 15
crops_size = (100,100)

for en, path in enumerate(videos[key]):
    print(en, path)

    if en < start_from:
        continue

    crops = get_person_crops(path, model_path='yolo11l.pt')

    print(f'crops length {len(crops)}')
    if not crops:
        continue
    
    crops_resized = resize_images(crops, crops_size)
    crops_resized_sample, _ = sub_sample(crops_resized, crops_number)
    array = np.concatenate(crops_resized_sample, axis=1)

    prefix = path.stem
    images = crops_resized_sample + [array]
    refPath = refPaths[key]
    save_images(images, refPath=refPath, prefix=prefix)
# Out:
# 0 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 1/Fall/13.mp4
# crops length 128
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 1 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 1/Fall/06.mp4
# crops length 141
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 2 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 1/Fall/12.mp4
# crops length 200
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 3 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 1/Fall/14.mp4
# crops length 169
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 4 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 1/Fall/10.mp4
# crops length 115
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 5 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 1/Fall/09.mp4
# crops length 82
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 6 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 1/Fall/01.mp4
# crops length 123
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 7 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 1/Fall/11.mp4
# crops length 181
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 8 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 1/Fall/07.mp4
# crops length 152
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 9 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 1/Fall/05.mp4
# crops length 162
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 10 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 1/Fall/08.mp4
# crops length 129
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 11 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 1/Fall/04.mp4
# crops length 123
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 12 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 1/Fall/15.mp4
# crops length 130
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 13 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 1/Fall/16.mp4
# crops length 185
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 14 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 1/Fall/02.mp4
# crops length 109
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 15 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 1/Fall/03.mp4
# crops length 175
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 16 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 2/Fall/13.mp4
# crops length 88
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 17 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 2/Fall/06.mp4
# crops length 193
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 18 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 2/Fall/12.mp4
# crops length 167
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 19 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 2/Fall/14.mp4
# crops length 63
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 20 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 2/Fall/19.mp4
# crops length 463
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 21 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 2/Fall/24.mp4
# crops length 213
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 22 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 2/Fall/10.mp4
# crops length 90
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 23 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 2/Fall/09.mp4
# crops length 154
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 24 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 2/Fall/01.mp4
# crops length 190
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 25 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 2/Fall/11.mp4
# crops length 133
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 26 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 2/Fall/07.mp4
# crops length 124
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 27 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 2/Fall/05.mp4
# crops length 133
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 28 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 2/Fall/08.mp4
# crops length 140
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 29 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 2/Fall/04.mp4
# crops length 207
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 30 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 2/Fall/15.mp4
# crops length 348
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 31 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 2/Fall/17.mp4
# crops length 194
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 32 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 2/Fall/16.mp4
# crops length 120
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 33 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 2/Fall/22.mp4
# crops length 155
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 34 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 2/Fall/02.mp4
# crops length 223
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 35 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 2/Fall/20.mp4
# crops length 342
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 36 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 2/Fall/18.mp4
# crops length 345
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 37 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 2/Fall/25.mp4
# crops length 218
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 38 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 2/Fall/03.mp4
# crops length 208
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 39 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 2/Fall/23.mp4
# crops length 225
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 40 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 2/Fall/21.mp4
# crops length 280
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 41 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 3/Fall/13.mp4
# crops length 121
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 42 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 3/Fall/06.mp4
# crops length 165
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 43 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 3/Fall/12.mp4
# crops length 127
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 44 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 3/Fall/14.mp4
# crops length 343
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 45 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 3/Fall/19.mp4
# crops length 57
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 46 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 3/Fall/10.mp4
# crops length 124
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 47 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 3/Fall/09.mp4
# crops length 187
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 48 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 3/Fall/01.mp4
# crops length 105
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 49 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 3/Fall/11.mp4
# crops length 266
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 50 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 3/Fall/07.mp4
# crops length 269
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 51 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 3/Fall/05.mp4
# crops length 295
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 52 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 3/Fall/08.mp4
# crops length 75
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 53 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 3/Fall/04.mp4
# crops length 159
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 54 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 3/Fall/15.mp4
# crops length 39
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 55 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 3/Fall/17.mp4
# crops length 98
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 56 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 3/Fall/16.mp4
# crops length 65
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 57 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 3/Fall/02.mp4
# crops length 175
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 58 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 3/Fall/20.mp4
# crops length 90
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 59 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 3/Fall/18.mp4
# crops length 74
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 60 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 3/Fall/03.mp4
# crops length 167
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 61 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 3/Fall/21.mp4
# crops length 274
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 62 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 4/Fall/13.mp4
# crops length 149
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 63 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 4/Fall/06.mp4
# crops length 142
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 64 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 4/Fall/12.mp4
# crops length 123
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 65 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 4/Fall/14.mp4
# crops length 121
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 66 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 4/Fall/10.mp4
# crops length 143
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 67 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 4/Fall/09.mp4
# crops length 181
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 68 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 4/Fall/01.mp4
# crops length 92
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 69 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 4/Fall/11.mp4
# crops length 135
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 70 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 4/Fall/07.mp4
# crops length 169
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 71 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 4/Fall/05.mp4
# crops length 219
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 72 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 4/Fall/08.mp4
# crops length 175
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 73 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 4/Fall/04.mp4
# crops length 93
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 74 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 4/Fall/15.mp4
# crops length 141
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 75 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 4/Fall/17.mp4
# crops length 207
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 76 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 4/Fall/16.mp4
# crops length 183
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 77 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 4/Fall/02.mp4
# crops length 78
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
# 78 ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Subject 4/Fall/03.mp4
# crops length 138
# Saved 16 images to ../GMDCSA24-A-Dataset-for-Human-Fall-Detection-in-Videos - Validation/Fall/Raw_Image
