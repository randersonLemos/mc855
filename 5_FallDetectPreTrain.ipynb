# %% [markdown]
# # MODULES

# %%
# !pip install pathlib
# !pip install matplotlib
# Out:
# Requirement already satisfied: pathlib in /home/zionsflow/anaconda3/envs/fallDetec/lib/python3.10/site-packages (1.0.1)
# Requirement already satisfied: matplotlib in /home/zionsflow/anaconda3/envs/fallDetec/lib/python3.10/site-packages (3.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/zionsflow/anaconda3/envs/fallDetec/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/zionsflow/anaconda3/envs/fallDetec/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/zionsflow/anaconda3/envs/fallDetec/lib/python3.10/site-packages (from matplotlib) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/zionsflow/anaconda3/envs/fallDetec/lib/python3.10/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /home/zionsflow/anaconda3/envs/fallDetec/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/zionsflow/anaconda3/envs/fallDetec/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/zionsflow/anaconda3/envs/fallDetec/lib/python3.10/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/zionsflow/anaconda3/envs/fallDetec/lib/python3.10/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/zionsflow/anaconda3/envs/fallDetec/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/zionsflow/anaconda3/envs/fallDetec/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# !nvidia-smi
# Out:
# Sat Oct 11 19:19:35 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.247.01             Driver Version: 535.247.01   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3060        Off | 00000000:01:00.0  On |                  N/A |
# |  0%   48C    P8              16W / 170W |    634MiB / 12288MiB |     18%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      1237      G   /usr/lib/xorg/Xorg                          134MiB |
# |    0   N/A  N/A      1527      G   /usr/bin/gnome-shell                         81MiB |
# |    0   N/A  N/A    963267      G   ...seed-version=20251005-180042.197000      411MiB |
# +---------------------------------------------------------------------------------------+

# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
print(torch.cuda.get_device_name(0))
# Out:
# 1.13.1+cu117
# 11.7
# NVIDIA GeForce RTX 3060

# %%
import cv2
import os
import math
import time
import random
import pathlib
import numpy as np
from ultralytics import YOLO
import matplotlib.pyplot as plt

# %% [markdown]
# # GLOBAL VARIABLES

# %%
ROOT_DIR_IMAGES = '../Kaggle'

# %% [markdown]
# # IMAGES

# %%
def get_image_paths(root_dir, include='*', exclude=[]):
  paths = []
  
  for path in pathlib.Path(root_dir).glob(include): 
    paths.append(path)

  paths = sorted(paths)

  return paths

    
def base_filename_organization(imagPaths):
    baseFileNames = {}
    for imagPath in imagPaths:
        baseFileName = '_'.join(str(imagPath.stem).split('_')[:-1])
        if baseFileName not in baseFileNames:
            baseFileNames[baseFileName] = []
        baseFileNames[baseFileName].append(imagPath)

    # Sort lists numerically by the last suffix
    for key in baseFileNames:
        baseFileNames[key].sort(
            key=lambda p: int(p.stem.split('_')[-1])
        )

    return baseFileNames


def remove_last_element(baseFileNames):
    for baseFileName in baseFileNames:
        imagPaths = baseFileNames[baseFileName]
        length = len(imagPaths)
        baseFileNameLength = baseFileName + f'_{length-1}'
        imagPaths = [imagPath for imagPath in imagPaths if baseFileNameLength not in str(imagPath)]
        baseFileNames[baseFileName] = imagPaths
    return baseFileNames


def rotate_image(image, angle):
    """Rotate image around its center without cropping."""
    h, w = image.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    cos, sin = abs(M[0, 0]), abs(M[0, 1])
    
    # compute new bounding dimensions
    new_w = int((h * sin) + (w * cos))
    new_h = int((h * cos) + (w * sin))
    
    # adjust rotation matrix
    M[0, 2] += (new_w / 2) - center[0]
    M[1, 2] += (new_h / 2) - center[1]
    
    return cv2.warpAffine(image, M, (new_w, new_h))

def make_composite_images(images_dict: dict, final_width: int, final_height: int, save_dir: str):
    """
    Creates composite images from dict of images using OpenCV.
    Generates 6 versions for each key, each with a global rotation applied.
    
    Args:
        images_dict (dict): {key: [list of image paths]}
        final_width (int): width of final composite image
        final_height (int): height of final composite image
        save_dir (str): directory to save composite results
    """
    pathlib.Path(save_dir).mkdir(parents=True, exist_ok=True)

    # Rotations to apply
    rotations = [-30, -15, 0, 15, 30]

    for key, img_paths in images_dict.items():
        n = len(img_paths)
        grid_size = math.ceil(math.sqrt(n))  # square-ish grid
        cell_w = final_width // grid_size
        cell_h = final_height // grid_size

        # Load all images once
        loaded_images = []
        for img_path in img_paths:
            img = cv2.imread(str(img_path))
            if img is None:
                print(f"⚠️ Could not load {img_path}")
                continue
            loaded_images.append(img)

        for i, angle in enumerate(rotations):
            # Black canvas
            composite = np.zeros((final_height, final_width, 3), dtype=np.uint8)

            for idx, img in enumerate(loaded_images):
                try:
                    rotated = rotate_image(img, angle)
                    resized = cv2.resize(rotated, (cell_w, cell_h), interpolation=cv2.INTER_AREA)

                    row, col = divmod(idx, grid_size)
                    y, x = row * cell_h, col * cell_w
                    composite[y:y+cell_h, x:x+cell_w] = resized
                except Exception as e:
                    print(f"⚠️ Error with image idx {idx}: {e}")

            out_path = str(pathlib.Path(save_dir) / f"{key}_{i+1}.jpg")
            cv2.imwrite(out_path, composite)
            print(f"✅ Saved {out_path} (rotation {angle}°)")

# %%
imagsPaths = {}
imagsPaths['fall']    = get_image_paths( ROOT_DIR_IMAGES + '/Fall/Raw_Image')
imagsPaths['no_fall'] = get_image_paths( ROOT_DIR_IMAGES + '/No_Fall/Raw_Image')

print(f"[INFO] videos dict keys: {list(imagsPaths.keys())}")
print(f"[INFO] videos['fall'] has {len(imagsPaths['fall'])} entries")
print(f"[INFO] videos['no_fall'] has {len(imagsPaths['no_fall'])} entries")
# Out:
# [INFO] videos dict keys: ['fall', 'no_fall']
# [INFO] videos['fall'] has 49985 entries
# [INFO] videos['no_fall'] has 61029 entries

# %%
BASEFILENAMES = {}

BASEFILENAMES['fall'] = base_filename_organization(imagsPaths['fall'])
BASEFILENAMES['no_fall'] = base_filename_organization(imagsPaths['no_fall'])
print( f"Fall {len(BASEFILENAMES['fall'])}")
print( f"No fall {len(BASEFILENAMES['no_fall'])}")
# Out:
# Fall 3136
# No fall 3822

# %% [markdown]
# ## Remove last image

# %%
BASEFILENAMES['fall'] = remove_last_element(BASEFILENAMES['fall'])
BASEFILENAMES['no_fall'] = remove_last_element(BASEFILENAMES['no_fall'])
print( f"Fall {len(BASEFILENAMES['fall'])}")
print( f"No fall {len(BASEFILENAMES['no_fall'])}")
# Out:
# Fall 3136
# No fall 3822

# %%
make_composite_images(BASEFILENAMES['fall'],  final_width=800, final_height=800, save_dir='../Kaggle/Fall/Square_Image_Rotated_Train')
# Out:
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101331_1.jpg (rotation -30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101331_2.jpg (rotation -15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101331_3.jpg (rotation 0°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101331_4.jpg (rotation 15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101331_5.jpg (rotation 30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101427_1.jpg (rotation -30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101427_2.jpg (rotation -15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101427_3.jpg (rotation 0°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101427_4.jpg (rotation 15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101427_5.jpg (rotation 30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101520_1.jpg (rotation -30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101520_2.jpg (rotation -15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101520_3.jpg (rotation 0°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101520_4.jpg (rotation 15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101520_5.jpg (rotation 30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101626_1.jpg (rotation -30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101626_2.jpg (rotation -15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101626_3.jpg (rotation 0°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101626_4.jpg (rotation 15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101626_5.jpg (rotation 30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101723_1.jpg (rotation -30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101723_2.jpg (rotation -15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101723_3.jpg (rotation 0°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101723_4.jpg (rotation 15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101723_5.jpg (rotation 30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101943_1.jpg (rotation -30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101943_2.jpg (rotation -15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101943_3.jpg (rotation 0°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101943_4.jpg (rotation 15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_101943_5.jpg (rotation 30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102048_1.jpg (rotation -30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102048_2.jpg (rotation -15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102048_3.jpg (rotation 0°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102048_4.jpg (rotation 15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102048_5.jpg (rotation 30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102146_1.jpg (rotation -30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102146_2.jpg (rotation -15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102146_3.jpg (rotation 0°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102146_4.jpg (rotation 15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102146_5.jpg (rotation 30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102330_1.jpg (rotation -30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102330_2.jpg (rotation -15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102330_3.jpg (rotation 0°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102330_4.jpg (rotation 15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102330_5.jpg (rotation 30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102649_1.jpg (rotation -30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102649_2.jpg (rotation -15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102649_3.jpg (rotation 0°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102649_4.jpg (rotation 15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102649_5.jpg (rotation 30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102739_1.jpg (rotation -30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102739_2.jpg (rotation -15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102739_3.jpg (rotation 0°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102739_4.jpg (rotation 15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102739_5.jpg (rotation 30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102926_1.jpg (rotation -30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102926_2.jpg (rotation -15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102926_3.jpg (rotation 0°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102926_4.jpg (rotation 15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_102926_5.jpg (rotation 30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103041_1.jpg (rotation -30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103041_2.jpg (rotation -15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103041_3.jpg (rotation 0°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103041_4.jpg (rotation 15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103041_5.jpg (rotation 30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103200_1.jpg (rotation -30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103200_2.jpg (rotation -15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103200_3.jpg (rotation 0°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103200_4.jpg (rotation 15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103200_5.jpg (rotation 30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103345_1.jpg (rotation -30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103345_2.jpg (rotation -15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103345_3.jpg (rotation 0°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103345_4.jpg (rotation 15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103345_5.jpg (rotation 30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103443_1.jpg (rotation -30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103443_2.jpg (rotation -15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103443_3.jpg (rotation 0°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103443_4.jpg (rotation 15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103443_5.jpg (rotation 30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103526_1.jpg (rotation -30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103526_2.jpg (rotation -15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103526_3.jpg (rotation 0°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103526_4.jpg (rotation 15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103526_5.jpg (rotation 30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103725_1.jpg (rotation -30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103725_2.jpg (rotation -15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103725_3.jpg (rotation 0°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103725_4.jpg (rotation 15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_103725_5.jpg (rotation 30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_104404_1.jpg (rotation -30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_104404_2.jpg (rotation -15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_104404_3.jpg (rotation 0°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_104404_4.jpg (rotation 15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_104404_5.jpg (rotation 30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_104512_1.jpg (rotation -30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_104512_2.jpg (rotation -15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_104512_3.jpg (rotation 0°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_104512_4.jpg (rotation 15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_104512_5.jpg (rotation 30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_104618_1.jpg (rotation -30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_104618_2.jpg (rotation -15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_104618_3.jpg (rotation 0°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_104618_4.jpg (rotation 15°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_104618_5.jpg (rotation 30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_104722_1.jpg (rotation -30°)
# ✅ Saved ../Kaggle/Fall/Square_Image_Rotated_Train/20240912_